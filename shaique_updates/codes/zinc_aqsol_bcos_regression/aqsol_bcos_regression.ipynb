# %%
import sys
from pathlib import Path

current_dir = Path.cwd()

project_root = current_dir.parents[2] 

if str(project_root) not in sys.path:
    
    sys.path.append(str(project_root))

print(f"Project root added: {project_root}")
# Out:
# Project root added: /Users/shaique/Desktop/BioInf_IMP/NMM_group/ICML/bcos_gnn/bcosgnn

# %%
import functools
import itertools
import operator
from typing import Any
import torch
from torch_geometric.data import Dataset, download_url
from torch.utils.data import random_split
import numpy as np
import polars as pl
import seaborn as sns
import matplotlib.pyplot as plt
import torch
from bcos.modules import BcosLinear, BcosSequential
from sklearn.model_selection import train_test_split
from torch.nn import BCEWithLogitsLoss
from torch_geometric.datasets import BA2MotifDataset
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from torch_geometric.nn import MessagePassing
from torch_geometric.nn.aggr import SumAggregation
from torch_geometric.utils import add_self_loops, degree
from torchmetrics import AUROC
from tqdm import tqdm
import os
import torch.nn.functional as F
from torch.nn import Linear, Sequential, ReLU, BatchNorm1d, Embedding
from torch_geometric.nn import GINEConv, global_mean_pool

# %%
from torch_geometric.datasets import AQSOL

data_dir = os.path.join(project_root, "data", "AQSOL")

train_set = AQSOL(root=data_dir, split='train')

val_set = AQSOL(root=data_dir, split='val')

test_set = AQSOL(root=data_dir, split='test')

train_loader = DataLoader(train_set, batch_size=32, shuffle=True)

val_loader = DataLoader(val_set, batch_size=32, shuffle=False)

test_loader = DataLoader(test_set, batch_size=32, shuffle=False)

dataset = AQSOL(root=data_dir)

num_atom_types = int(dataset.data.x.max()) + 1

num_bond_types = int(dataset.data.edge_attr.max()) + 1

print(f"Total Atom Types: {num_atom_types}")

print(f"Total Bond Types: {num_bond_types}")

def get_stats(split_name):

    dataset = AQSOL(root = data_dir , split = split_name)

    num_graphs = len(dataset)

    num_nodes = sum([d.num_nodes for d in dataset])/num_graphs

    num_edges = sum([d.num_edges for d in dataset])/num_graphs

    print(f'{split_name} set statistics:')
    print(f'Number of graphs: {num_graphs}')
    print(f'Average number of nodes per graph: {num_nodes}')
    print(f'Average number of edges per graph: {num_edges}')

    return dataset
train_stats = get_stats("train")
val_stats = get_stats("val")
test_stats = get_stats("test")
# Out:
# /var/folders/7z/v5vlp84n7pl7lqlv_7xw5_z40000gn/T/ipykernel_15315/2878740469.py:19: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   num_atom_types = int(dataset.data.x.max()) + 1
# /var/folders/7z/v5vlp84n7pl7lqlv_7xw5_z40000gn/T/ipykernel_15315/2878740469.py:21: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   num_bond_types = int(dataset.data.edge_attr.max()) + 1
# Total Atom Types: 65
# Total Bond Types: 5
# train set statistics:
# Number of graphs: 7836
# Average number of nodes per graph: 15.420239918325676
# Average number of edges per graph: 30.66309341500766
# val set statistics:
# Number of graphs: 998
# Average number of nodes per graph: 23.48997995991984
# Average number of edges per graph: 50.75551102204409
# test set statistics:
# Number of graphs: 999
# Average number of nodes per graph: 28.663663663663662
# Average number of edges per graph: 61.131131131131134

# %%
# Find number of atom types (node features)
# .x usually has shape [num_nodes, 1] for AQSOL
num_atom_types = int(dataset.data.x.max()) + 1

# Find number of bond types (edge features)
# .edge_attr usually has shape [num_edges, 1]
num_bond_types = int(dataset.data.edge_attr.max()) + 1

print(f"Total Atom Types: {num_atom_types}")
print(f"Total Bond Types: {num_bond_types}")
# Out:
# Downloading https://www.dropbox.com/s/lzu9lmukwov12kt/aqsol_graph_raw.zip?dl=1
# Extracting data/AQSOL/aqsol_graph_raw.zip
# Processing...
# Total Atom Types: 65
# Total Bond Types: 5
# Done!
# /var/folders/7z/v5vlp84n7pl7lqlv_7xw5_z40000gn/T/ipykernel_15315/4219971455.py:5: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   num_atom_types = int(dataset.data.x.max()) + 1
# /var/folders/7z/v5vlp84n7pl7lqlv_7xw5_z40000gn/T/ipykernel_15315/4219971455.py:9: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   num_bond_types = int(dataset.data.edge_attr.max()) + 1

# %%
class SimpleGINE(torch.nn.Module):
    def __init__(self, hidden_dim=256):
        super(SimpleGINE, self).__init__()
        
        # 1. Input Embeddings (Atom types and Bond types)
        self.node_emb = Embedding(65, hidden_dim)
        self.edge_emb = Embedding(5, hidden_dim)

        # 2. GINE Layer 1
        self.mlp1 = Sequential(Linear(hidden_dim, hidden_dim), ReLU(), Linear(hidden_dim, hidden_dim))
        self.conv1 = GINEConv(self.mlp1)
        self.bn1 = BatchNorm1d(hidden_dim)

        # 3. GINE Layer 2
        self.mlp2 = Sequential(Linear(hidden_dim, hidden_dim), ReLU(), Linear(hidden_dim, hidden_dim))
        self.conv2 = GINEConv(self.mlp2)
        self.bn2 = BatchNorm1d(hidden_dim)

        # 4. GINE Layer 3
        self.mlp3 = Sequential(Linear(hidden_dim, hidden_dim), ReLU(), Linear(hidden_dim, hidden_dim))
        self.conv3 = GINEConv(self.mlp3)
        self.bn3 = BatchNorm1d(hidden_dim)

        # 4. GINE Layer 4
        self.mlp4 = Sequential(Linear(hidden_dim, hidden_dim), ReLU(), Linear(hidden_dim, hidden_dim))
        self.conv4 = GINEConv(self.mlp4)
        self.bn4 = BatchNorm1d(hidden_dim)

        # 5. Final Readout
        self.post_mp = Sequential(
            Linear(hidden_dim, hidden_dim // 2), 
            ReLU(), 
            Linear(hidden_dim // 2, 1)
        )

    def forward(self, x, edge_index, edge_attr, batch):
        # Convert raw integer features to embeddings
        x = self.node_emb(x.squeeze(-1))
        edge_attr = self.edge_emb(edge_attr)

        # Layer 1
        x = self.conv1(x, edge_index, edge_attr)
        x = self.bn1(x)
        x = F.relu(x)

        # Layer 2
        x = self.conv2(x, edge_index, edge_attr)
        x = self.bn2(x)
        x = F.relu(x)

        # Layer 3
        x = self.conv3(x, edge_index, edge_attr)
        x = self.bn3(x)
        x = F.relu(x)

        # Layer 4
        x = self.conv4(x, edge_index, edge_attr)
        x = self.bn4(x)
        x = F.relu(x)

        # Global Pooling (Graph-level representation)
        x = global_mean_pool(x, batch)

        # Regression Output
        return self.post_mp(x).view(-1)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimpleGINE(hidden_dim=256).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=15 , min_lr=1e-6)

train_loader = DataLoader(train_set, batch_size=128, shuffle=True)
val_loader = DataLoader(val_set, batch_size=128)
test_loader = DataLoader(test_set, batch_size=128)

def train():
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data.x, data.edge_index, data.edge_attr, data.batch)
        loss = F.l1_loss(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    return total_loss / len(train_set)

@torch.no_grad()
def test(loader):
    model.eval()
    total_mae = 0
    for data in loader:
        data = data.to(device)
        out = model(data.x, data.edge_index, data.edge_attr, data.batch)
        total_mae += F.l1_loss(out, data.y).item() * data.num_graphs
    return total_mae / len(loader.dataset)

train_maes, val_maes = [], []
for epoch in range(1, 101):
    t_mae = train()
    v_mae = test(val_loader)
    train_maes.append(t_mae)
    val_maes.append(v_mae)
    scheduler.step(v_mae)
    #if epoch % 10 == 0:
    print(f"Epoch {epoch:03d} | Train MAE: {t_mae:.4f} | Val MAE: {v_mae:.4f}")

# Final Plotting
plt.figure(figsize=(8, 5))
plt.plot(train_maes, label='Train MAE')
plt.plot(val_maes, label='Val MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.title('ZINC Training Progress')
plt.legend()
plt.show()

# Final Inference
final_test_mae = test(test_loader)
print(f"\nFinal Test MAE: {final_test_mae:.4f}")
# Out:
# Epoch 001 | Train MAE: 1.3673 | Val MAE: 1.6179
# Epoch 002 | Train MAE: 1.0916 | Val MAE: 1.2684
# Epoch 003 | Train MAE: 1.0241 | Val MAE: 2.0489
# Epoch 004 | Train MAE: 0.9795 | Val MAE: 2.6300
# Epoch 005 | Train MAE: 0.9918 | Val MAE: 1.6339
# Epoch 006 | Train MAE: 0.9466 | Val MAE: 2.3269
# Epoch 007 | Train MAE: 0.9028 | Val MAE: 1.2625
# Epoch 008 | Train MAE: 0.9158 | Val MAE: 1.7781
# Epoch 009 | Train MAE: 0.9005 | Val MAE: 1.2752
# Epoch 010 | Train MAE: 0.8770 | Val MAE: 1.2045
# Epoch 011 | Train MAE: 0.8579 | Val MAE: 1.8425
# Epoch 012 | Train MAE: 0.8455 | Val MAE: 1.3039
# Epoch 013 | Train MAE: 0.8535 | Val MAE: 1.1998
# Epoch 014 | Train MAE: 0.8358 | Val MAE: 1.1170
# Epoch 015 | Train MAE: 0.8362 | Val MAE: 1.1669
# Epoch 016 | Train MAE: 0.8088 | Val MAE: 1.3051
# Epoch 017 | Train MAE: 0.8246 | Val MAE: 1.1228
# Epoch 018 | Train MAE: 0.7977 | Val MAE: 1.1225
# Epoch 019 | Train MAE: 0.7836 | Val MAE: 1.3822
# Epoch 020 | Train MAE: 0.7839 | Val MAE: 1.1059
# Epoch 021 | Train MAE: 0.7611 | Val MAE: 1.1292
# Epoch 022 | Train MAE: 0.7470 | Val MAE: 1.1325
# Epoch 023 | Train MAE: 0.7530 | Val MAE: 1.0801
# Epoch 024 | Train MAE: 0.7458 | Val MAE: 1.1433
# Epoch 025 | Train MAE: 0.7315 | Val MAE: 1.3035
# Epoch 026 | Train MAE: 0.7364 | Val MAE: 1.1131
# Epoch 027 | Train MAE: 0.7309 | Val MAE: 1.4336
# Epoch 028 | Train MAE: 0.7317 | Val MAE: 1.0739
# Epoch 029 | Train MAE: 0.7307 | Val MAE: 1.1711
# Epoch 030 | Train MAE: 0.7315 | Val MAE: 1.1191
# Epoch 031 | Train MAE: 0.7252 | Val MAE: 1.1263
# Epoch 032 | Train MAE: 0.7202 | Val MAE: 1.2998
# Epoch 033 | Train MAE: 0.7052 | Val MAE: 1.0493
# Epoch 034 | Train MAE: 0.6973 | Val MAE: 1.4110
# Epoch 035 | Train MAE: 0.6876 | Val MAE: 1.0366
# Epoch 036 | Train MAE: 0.6868 | Val MAE: 1.1824
# Epoch 037 | Train MAE: 0.7232 | Val MAE: 1.1044
# Epoch 038 | Train MAE: 0.6762 | Val MAE: 1.4881
# Epoch 039 | Train MAE: 0.6970 | Val MAE: 1.2310
# Epoch 040 | Train MAE: 0.6869 | Val MAE: 1.0414
# Epoch 041 | Train MAE: 0.6661 | Val MAE: 1.1392
# Epoch 042 | Train MAE: 0.6669 | Val MAE: 1.1148
# Epoch 043 | Train MAE: 0.6845 | Val MAE: 1.0564
# Epoch 044 | Train MAE: 0.6663 | Val MAE: 1.0784
# Epoch 045 | Train MAE: 0.6512 | Val MAE: 1.0834
# Epoch 046 | Train MAE: 0.6474 | Val MAE: 1.1339
# Epoch 047 | Train MAE: 0.6517 | Val MAE: 1.0258
# Epoch 048 | Train MAE: 0.6518 | Val MAE: 1.0727
# Epoch 049 | Train MAE: 0.6492 | Val MAE: 1.1545
# Epoch 050 | Train MAE: 0.6345 | Val MAE: 1.0682
# Epoch 051 | Train MAE: 0.6361 | Val MAE: 1.0812
# Epoch 052 | Train MAE: 0.6272 | Val MAE: 1.1807
# Epoch 053 | Train MAE: 0.6349 | Val MAE: 1.0380
# Epoch 054 | Train MAE: 0.6478 | Val MAE: 1.0825
# Epoch 055 | Train MAE: 0.6219 | Val MAE: 1.0950
# Epoch 056 | Train MAE: 0.6136 | Val MAE: 1.0914
# Epoch 057 | Train MAE: 0.6347 | Val MAE: 1.0171
# Epoch 058 | Train MAE: 0.6288 | Val MAE: 1.2768
# Epoch 059 | Train MAE: 0.6409 | Val MAE: 1.1857
# Epoch 060 | Train MAE: 0.6214 | Val MAE: 1.0921
# Epoch 061 | Train MAE: 0.6176 | Val MAE: 1.2178
# Epoch 062 | Train MAE: 0.5994 | Val MAE: 1.0391
# Epoch 063 | Train MAE: 0.6014 | Val MAE: 1.0695
# Epoch 064 | Train MAE: 0.6080 | Val MAE: 1.0604
# Epoch 065 | Train MAE: 0.5972 | Val MAE: 1.0954
# Epoch 066 | Train MAE: 0.5822 | Val MAE: 1.1617
# Epoch 067 | Train MAE: 0.5936 | Val MAE: 1.0586
# Epoch 068 | Train MAE: 0.5886 | Val MAE: 1.0389
# Epoch 069 | Train MAE: 0.5822 | Val MAE: 1.0529
# Epoch 070 | Train MAE: 0.5831 | Val MAE: 1.0652
# Epoch 071 | Train MAE: 0.5815 | Val MAE: 1.0094
# Epoch 072 | Train MAE: 0.5880 | Val MAE: 1.0950
# Epoch 073 | Train MAE: 0.5828 | Val MAE: 1.0712
# Epoch 074 | Train MAE: 0.5862 | Val MAE: 1.0764
# Epoch 075 | Train MAE: 0.5777 | Val MAE: 1.0643
# Epoch 076 | Train MAE: 0.5780 | Val MAE: 1.0402
# Epoch 077 | Train MAE: 0.5821 | Val MAE: 1.0829
# Epoch 078 | Train MAE: 0.5842 | Val MAE: 1.0570
# Epoch 079 | Train MAE: 0.5701 | Val MAE: 1.0474
# Epoch 080 | Train MAE: 0.5867 | Val MAE: 1.0393
# Epoch 081 | Train MAE: 0.5769 | Val MAE: 1.0733
# Epoch 082 | Train MAE: 0.5635 | Val MAE: 1.0819
# Epoch 083 | Train MAE: 0.5729 | Val MAE: 1.0346
# Epoch 084 | Train MAE: 0.5651 | Val MAE: 1.0605
# Epoch 085 | Train MAE: 0.5598 | Val MAE: 1.1139
# Epoch 086 | Train MAE: 0.5573 | Val MAE: 1.0062
# Epoch 087 | Train MAE: 0.5624 | Val MAE: 1.0068
# Epoch 088 | Train MAE: 0.5848 | Val MAE: 1.0404
# Epoch 089 | Train MAE: 0.5550 | Val MAE: 0.9973
# Epoch 090 | Train MAE: 0.5547 | Val MAE: 1.0077
# Epoch 091 | Train MAE: 0.5558 | Val MAE: 1.2402
# Epoch 092 | Train MAE: 0.5463 | Val MAE: 1.0769
# Epoch 093 | Train MAE: 0.5606 | Val MAE: 1.0727
# Epoch 094 | Train MAE: 0.5682 | Val MAE: 1.0350
# Epoch 095 | Train MAE: 0.5353 | Val MAE: 1.0795
# Epoch 096 | Train MAE: 0.5363 | Val MAE: 1.0933
# Epoch 097 | Train MAE: 0.5396 | Val MAE: 1.0083
# Epoch 098 | Train MAE: 0.5518 | Val MAE: 1.1014
# Epoch 099 | Train MAE: 0.5542 | Val MAE: 1.0494
# Epoch 100 | Train MAE: 0.5293 | Val MAE: 1.0196
# Final Test MAE: 1.2600

# %% [markdown]
# ## BCos GINE (edge-aware) on ZINC
# This section defines a BCos version of GINE (uses `edge_attr`) so the comparison with the vanilla `GINEConv` model above is faithful.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import MessagePassing
from torch_geometric.nn.aggr import MeanAggregation


class Readout(nn.Module):
    def __init__(self, in_channels: int, hidden_channels: int | None = None, out_channels: int = 1, *, b: float = 2, max_out: int = 1):
        super().__init__()
        if hidden_channels is None:
            self.readout = BcosLinear(in_channels, out_channels, b=b, max_out=max_out)
        else:
            self.readout = nn.Sequential(
                BcosLinear(in_channels, hidden_channels, b=b, max_out=max_out),
                nn.ReLU(),
                BcosLinear(hidden_channels, out_channels, b=b, max_out=max_out),
            )

    def forward(self, x: torch.Tensor, batch: torch.Tensor) -> torch.Tensor:
        raise NotImplementedError


class ReadoutThenAgg(Readout):
    def __init__(self, in_channels: int, hidden_channels: int | None = None, out_channels: int = 1, *, b: float = 2, max_out: int = 1):
        super().__init__(in_channels, hidden_channels, out_channels, b=b, max_out=max_out)
        # Use mean aggregation to match `global_mean_pool` used in the vanilla GINE baseline.
        self.agg = MeanAggregation()

    def forward(self, x: torch.Tensor, batch: torch.Tensor) -> torch.Tensor:
        z = self.readout(x)
        out = self.agg(z, batch)
        return out


class BcosGINEConv(MessagePassing):
    def __init__(
        self,
        hidden_dim: int,
        *,
        b: float = 2,
        max_out: int = 1,
        eps: float = 0.0,
        train_eps: bool = False,
    ):
        super().__init__(aggr="add")
        self.nn = nn.Sequential(
            BcosLinear(hidden_dim, hidden_dim, b=b, max_out=max_out),
            nn.ReLU(),
            BcosLinear(hidden_dim, hidden_dim, b=b, max_out=max_out),
        )
        if train_eps:
            self.eps = nn.Parameter(torch.tensor([eps], dtype=torch.float))
        else:
            self.register_buffer("eps", torch.tensor([eps], dtype=torch.float))

    def forward(self, x: torch.Tensor, edge_index: torch.Tensor, edge_attr: torch.Tensor) -> torch.Tensor:
        out = self.propagate(edge_index, x=x, edge_attr=edge_attr)
        out = (1 + self.eps) * x + out
        return self.nn(out)

    def message(self, x_j: torch.Tensor, edge_attr: torch.Tensor) -> torch.Tensor:
        # GINE-style message: ReLU(x_j + e_ij)
        return F.relu(x_j + edge_attr)

# %%
class BCosGINE(nn.Module):
    def __init__(self, hidden_dim: int = 256, *, b: float = 2, max_out: int = 1):
        super().__init__()
        # Match the vanilla baseline: same vocab sizes and embedding dim.
        self.node_emb = nn.Embedding(65, hidden_dim)
        self.edge_emb = nn.Embedding(5, hidden_dim)

        # Match the vanilla baseline: 3 GINE-style conv blocks + BN + ReLU.
        self.conv1 = BcosGINEConv(hidden_dim, b=b, max_out=max_out)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.conv2 = BcosGINEConv(hidden_dim, b=b, max_out=max_out)
        self.bn2 = nn.BatchNorm1d(hidden_dim)
        self.conv3 = BcosGINEConv(hidden_dim, b=b, max_out=max_out)
        self.bn3 = nn.BatchNorm1d(hidden_dim)

        # Use ReadoutThenAgg as requested (mean aggregation to align with `global_mean_pool`).
        self.readout = ReadoutThenAgg(hidden_dim, hidden_dim // 2, out_channels=1, b=b, max_out=max_out)

    def forward(self, x: torch.Tensor, edge_index: torch.Tensor, edge_attr: torch.Tensor, batch: torch.Tensor) -> torch.Tensor:
        x = self.node_emb(x.squeeze(-1).long())
        edge_attr = edge_attr.view(-1).long()
        edge_attr = self.edge_emb(edge_attr)

        x = self.conv1(x, edge_index, edge_attr)
        x = self.bn1(x)
        x = F.relu(x)

        x = self.conv2(x, edge_index, edge_attr)
        x = self.bn2(x)
        x = F.relu(x)

        x = self.conv3(x, edge_index, edge_attr)
        x = self.bn3(x)
        x = F.relu(x)

        out = self.readout(x, batch)
        return out.view(-1)

# %%
from copy import deepcopy


def _bcos_train_one_epoch(model: nn.Module, loader, optimizer: torch.optim.Optimizer, device: torch.device) -> float:
    model.train()
    total_mae = 0.0
    for data in loader:
        data = data.to(device)
        optimizer.zero_grad(set_to_none=True)
        out = model(data.x, data.edge_index, data.edge_attr, data.batch)
        loss = F.l1_loss(out, data.y)
        loss.backward()
        optimizer.step()
        total_mae += loss.detach().item() * data.num_graphs
    return total_mae / len(loader.dataset)


@torch.no_grad()
def _bcos_eval_mae(model: nn.Module, loader, device: torch.device) -> float:
    model.eval()
    total_mae = 0.0
    for data in loader:
        data = data.to(device)
        out = model(data.x, data.edge_index, data.edge_attr, data.batch)
        total_mae += F.l1_loss(out, data.y).item() * data.num_graphs
    return total_mae / len(loader.dataset)

# %%
# Match the vanilla baseline hyperparams as closely as possible.
bcos_device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
bcos_model = BCosGINE(hidden_dim=256, b=2, max_out=1).to(bcos_device)

bcos_optimizer = torch.optim.Adam(bcos_model.parameters(), lr=0.001)
bcos_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    bcos_optimizer, mode='min', factor=0.5, patience=15, min_lr=1e-6
 )

num_epochs = 100  # set to 100 to match the vanilla run above
bcos_train_maes, bcos_val_maes = [], []
best_val = float('inf')
best_state = None

for epoch in range(1, num_epochs + 1):
    train_mae = _bcos_train_one_epoch(bcos_model, train_loader, bcos_optimizer, bcos_device)
    val_mae = _bcos_eval_mae(bcos_model, val_loader, bcos_device)
    bcos_train_maes.append(train_mae)
    bcos_val_maes.append(val_mae)
    bcos_scheduler.step(val_mae)

    if val_mae < best_val:
        best_val = val_mae
        best_state = deepcopy(bcos_model.state_dict())

    print(f"[BCosGINE] Epoch {epoch:03d} | Train MAE: {train_mae:.4f} | Val MAE: {val_mae:.4f}")

if best_state is not None:
    bcos_model.load_state_dict(best_state)

bcos_test_mae = _bcos_eval_mae(bcos_model, test_loader, bcos_device)
print(f"\n[BCosGINE] Best Val MAE: {best_val:.4f}")
print(f"[BCosGINE] Final Test MAE: {bcos_test_mae:.4f}")

# Plot curves (same style as vanilla)
plt.figure(figsize=(8, 5))
plt.plot(bcos_train_maes, label='BCos Train MAE')
plt.plot(bcos_val_maes, label='BCos Val MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.title('BCosGINE Training Progress (AQSOL)')
plt.legend()
plt.show()
# Out:
# [BCosGINE] Epoch 001 | Train MAE: 1.5270 | Val MAE: 1.6365
# [BCosGINE] Epoch 002 | Train MAE: 1.0798 | Val MAE: 1.3157
# [BCosGINE] Epoch 003 | Train MAE: 1.0300 | Val MAE: 1.2411
# [BCosGINE] Epoch 004 | Train MAE: 1.0061 | Val MAE: 1.4764
# [BCosGINE] Epoch 005 | Train MAE: 0.9867 | Val MAE: 1.5108
# [BCosGINE] Epoch 006 | Train MAE: 0.9796 | Val MAE: 1.8912
# [BCosGINE] Epoch 007 | Train MAE: 0.9381 | Val MAE: 1.1906
# [BCosGINE] Epoch 008 | Train MAE: 0.9526 | Val MAE: 1.5394
# [BCosGINE] Epoch 009 | Train MAE: 0.9319 | Val MAE: 1.3269
# [BCosGINE] Epoch 010 | Train MAE: 0.9217 | Val MAE: 1.1762
# [BCosGINE] Epoch 011 | Train MAE: 0.8854 | Val MAE: 1.2527
# [BCosGINE] Epoch 012 | Train MAE: 0.8920 | Val MAE: 1.1814
# [BCosGINE] Epoch 013 | Train MAE: 0.8682 | Val MAE: 1.1953
# [BCosGINE] Epoch 014 | Train MAE: 0.8755 | Val MAE: 1.1501
# [BCosGINE] Epoch 015 | Train MAE: 0.8595 | Val MAE: 1.3374
# [BCosGINE] Epoch 016 | Train MAE: 0.8703 | Val MAE: 1.1190
# [BCosGINE] Epoch 017 | Train MAE: 0.8419 | Val MAE: 1.4226
# [BCosGINE] Epoch 018 | Train MAE: 0.8510 | Val MAE: 1.5409
# [BCosGINE] Epoch 019 | Train MAE: 0.8467 | Val MAE: 1.2359
# [BCosGINE] Epoch 020 | Train MAE: 0.8270 | Val MAE: 1.3024
# [BCosGINE] Epoch 021 | Train MAE: 0.8176 | Val MAE: 1.1773
# [BCosGINE] Epoch 022 | Train MAE: 0.8118 | Val MAE: 1.1756
# [BCosGINE] Epoch 023 | Train MAE: 0.8010 | Val MAE: 1.6606
# [BCosGINE] Epoch 024 | Train MAE: 0.8050 | Val MAE: 1.2708
# [BCosGINE] Epoch 025 | Train MAE: 0.7876 | Val MAE: 1.2868
# [BCosGINE] Epoch 026 | Train MAE: 0.7947 | Val MAE: 1.3014
# [BCosGINE] Epoch 027 | Train MAE: 0.7909 | Val MAE: 1.2752
# [BCosGINE] Epoch 028 | Train MAE: 0.7994 | Val MAE: 1.3216
# [BCosGINE] Epoch 029 | Train MAE: 0.7825 | Val MAE: 1.1600
# [BCosGINE] Epoch 030 | Train MAE: 0.7691 | Val MAE: 1.3121
# [BCosGINE] Epoch 031 | Train MAE: 0.7724 | Val MAE: 1.1766
# [BCosGINE] Epoch 032 | Train MAE: 0.7654 | Val MAE: 1.2133
# [BCosGINE] Epoch 033 | Train MAE: 0.7232 | Val MAE: 1.1859
# [BCosGINE] Epoch 034 | Train MAE: 0.7135 | Val MAE: 1.1440
# [BCosGINE] Epoch 035 | Train MAE: 0.7192 | Val MAE: 1.0960
# [BCosGINE] Epoch 036 | Train MAE: 0.7091 | Val MAE: 1.1416
# [BCosGINE] Epoch 037 | Train MAE: 0.7029 | Val MAE: 1.1262
# [BCosGINE] Epoch 038 | Train MAE: 0.7040 | Val MAE: 1.1356
# [BCosGINE] Epoch 039 | Train MAE: 0.7046 | Val MAE: 1.1082
# [BCosGINE] Epoch 040 | Train MAE: 0.7019 | Val MAE: 1.0990
# [BCosGINE] Epoch 041 | Train MAE: 0.7007 | Val MAE: 1.0825
# [BCosGINE] Epoch 042 | Train MAE: 0.6910 | Val MAE: 1.1972
# [BCosGINE] Epoch 043 | Train MAE: 0.6843 | Val MAE: 1.0969
# [BCosGINE] Epoch 044 | Train MAE: 0.6890 | Val MAE: 1.1649
# [BCosGINE] Epoch 045 | Train MAE: 0.6829 | Val MAE: 1.0972
# [BCosGINE] Epoch 046 | Train MAE: 0.6790 | Val MAE: 1.1056
# [BCosGINE] Epoch 047 | Train MAE: 0.6906 | Val MAE: 1.1363
# [BCosGINE] Epoch 048 | Train MAE: 0.6822 | Val MAE: 1.1281
# [BCosGINE] Epoch 049 | Train MAE: 0.6703 | Val MAE: 1.1265
# [BCosGINE] Epoch 050 | Train MAE: 0.6770 | Val MAE: 1.1858
# [BCosGINE] Epoch 051 | Train MAE: 0.6776 | Val MAE: 1.1485
# [BCosGINE] Epoch 052 | Train MAE: 0.6670 | Val MAE: 1.1044
# [BCosGINE] Epoch 053 | Train MAE: 0.6574 | Val MAE: 1.2298
# [BCosGINE] Epoch 054 | Train MAE: 0.6662 | Val MAE: 1.2377
# [BCosGINE] Epoch 055 | Train MAE: 0.6620 | Val MAE: 1.1017
# [BCosGINE] Epoch 056 | Train MAE: 0.6581 | Val MAE: 1.1261
# [BCosGINE] Epoch 057 | Train MAE: 0.6511 | Val MAE: 1.1025
# [BCosGINE] Epoch 058 | Train MAE: 0.6306 | Val MAE: 1.0726
# [BCosGINE] Epoch 059 | Train MAE: 0.6284 | Val MAE: 1.1068
# [BCosGINE] Epoch 060 | Train MAE: 0.6262 | Val MAE: 1.0676
# [BCosGINE] Epoch 061 | Train MAE: 0.6296 | Val MAE: 1.1106
# [BCosGINE] Epoch 062 | Train MAE: 0.6265 | Val MAE: 1.0970
# [BCosGINE] Epoch 063 | Train MAE: 0.6241 | Val MAE: 1.1084
# [BCosGINE] Epoch 064 | Train MAE: 0.6192 | Val MAE: 1.1126
# [BCosGINE] Epoch 065 | Train MAE: 0.6142 | Val MAE: 1.1237
# [BCosGINE] Epoch 066 | Train MAE: 0.6165 | Val MAE: 1.0953
# [BCosGINE] Epoch 067 | Train MAE: 0.6125 | Val MAE: 1.0967
# [BCosGINE] Epoch 068 | Train MAE: 0.6186 | Val MAE: 1.1144
# [BCosGINE] Epoch 069 | Train MAE: 0.6150 | Val MAE: 1.0924
# [BCosGINE] Epoch 070 | Train MAE: 0.6105 | Val MAE: 1.1272
# [BCosGINE] Epoch 071 | Train MAE: 0.6119 | Val MAE: 1.0993
# [BCosGINE] Epoch 072 | Train MAE: 0.6129 | Val MAE: 1.1076
# [BCosGINE] Epoch 073 | Train MAE: 0.6015 | Val MAE: 1.1019
# [BCosGINE] Epoch 074 | Train MAE: 0.6070 | Val MAE: 1.1050
# [BCosGINE] Epoch 075 | Train MAE: 0.6057 | Val MAE: 1.1069
# [BCosGINE] Epoch 076 | Train MAE: 0.6041 | Val MAE: 1.1292
# [BCosGINE] Epoch 077 | Train MAE: 0.5835 | Val MAE: 1.1328
# [BCosGINE] Epoch 078 | Train MAE: 0.5817 | Val MAE: 1.1180
# [BCosGINE] Epoch 079 | Train MAE: 0.5800 | Val MAE: 1.1323
# [BCosGINE] Epoch 080 | Train MAE: 0.5805 | Val MAE: 1.0936
# [BCosGINE] Epoch 081 | Train MAE: 0.5759 | Val MAE: 1.0907
# [BCosGINE] Epoch 082 | Train MAE: 0.5727 | Val MAE: 1.1065
# [BCosGINE] Epoch 083 | Train MAE: 0.5744 | Val MAE: 1.0954
# [BCosGINE] Epoch 084 | Train MAE: 0.5750 | Val MAE: 1.1054
# [BCosGINE] Epoch 085 | Train MAE: 0.5744 | Val MAE: 1.1233
# [BCosGINE] Epoch 086 | Train MAE: 0.5742 | Val MAE: 1.1036
# [BCosGINE] Epoch 087 | Train MAE: 0.5724 | Val MAE: 1.1099
# [BCosGINE] Epoch 088 | Train MAE: 0.5684 | Val MAE: 1.1263
# [BCosGINE] Epoch 089 | Train MAE: 0.5731 | Val MAE: 1.1020
# [BCosGINE] Epoch 090 | Train MAE: 0.5715 | Val MAE: 1.1225
# [BCosGINE] Epoch 091 | Train MAE: 0.5671 | Val MAE: 1.1315
# [BCosGINE] Epoch 092 | Train MAE: 0.5696 | Val MAE: 1.1204
# [BCosGINE] Epoch 093 | Train MAE: 0.5570 | Val MAE: 1.0903
# [BCosGINE] Epoch 094 | Train MAE: 0.5608 | Val MAE: 1.1100
# [BCosGINE] Epoch 095 | Train MAE: 0.5577 | Val MAE: 1.1133
# [BCosGINE] Epoch 096 | Train MAE: 0.5537 | Val MAE: 1.0956
# [BCosGINE] Epoch 097 | Train MAE: 0.5525 | Val MAE: 1.1078
# [BCosGINE] Epoch 098 | Train MAE: 0.5559 | Val MAE: 1.0997
# [BCosGINE] Epoch 099 | Train MAE: 0.5524 | Val MAE: 1.0951
# [BCosGINE] Epoch 100 | Train MAE: 0.5526 | Val MAE: 1.0937
#
# [BCosGINE] Best Val MAE: 1.0676
# [BCosGINE] Final Test MAE: 1.4288
